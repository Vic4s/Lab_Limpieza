# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Limpieza de Datos
#
# En este laboratorio usaremos el DataFrame de Netflix completo creado en los primeros laboratorios de Pandas.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.
#
# 3. Documenta todas las funciones creadas durante el ejercicio.
#
# 4. Debes incluir después de cada gráfica la interpretación de las mismas en una celda de markdown.

# %% [markdown]
# ## Parte 1: Limpieza y Preparación de Datos

# %% [markdown]
# #### Ejercicio 1: Estandarización y limpieza de columnas
#
# En este ejercicio, debes limpiar y estandarizar algunas columnas clave para hacerlas más manejables y consistentes en tus análisis. Específicamente, trabajarás con las columnas `date_added` y `duration` para convertirlas a un formato uniforme y estructurado.
#
# Instrucciones:
#
# 1. **Convertir la columna `date_added`**: La columna `date_added` contiene fechas en formato de texto. Debes convertirla a un formato `datetime` que pandas pueda entender y manejar fácilmente.
#
# 2. **Limpiar la columna `duration`**: La columna `duration` tiene valores en diferentes formatos como "1 Season", "2 Seasons", "90 min", etc. Tu tarea es extraer el número (ya sea el número de temporadas o la cantidad de minutos) y crear una nueva columna llamada `duration_cleaned` con esos valores estandarizados.
#
#
# **Resultado Esperado:**
# Deberás obtener algo como esto:
#
# | duration   | duration_cleaned |
# |------------|-----------------|
# | 1 Season   | 1               |
# | 90 min     | 90              |
# | 2 Seasons  | 2               |
# | 45 min     | 45              |
# | 3 Seasons  | 3               |

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Para guardar DataFrames en Excel
# -----------------------------------------------------------------------
from pandas import ExcelWriter

# Para generar todas las posibles combinaciones
# -----------------------------------------------------------------------
import itertools

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
# cargamos el dataframe creado en la lección anterior
df = pd.read_csv("datos/Netflix_Merge.csv", index_col = 0)

df.sample(5)
# Out:
#             type                                             Title  \
# show_id
# s1013    TV Show                          Luis Miguel - The Series
# s8648      Movie                       Twisted Trunk, Big Fat Body
# s1352      Movie  Our Lady of San Juan, Four Centuries of Miracles
# s3807    TV Show                                  Prince of Peoria
# s4163    TV Show                    A Taiwanese Tale of Two Cities
#
#              director                                               cast  \
# show_id
# s1013             NaN  Diego Boneta, Juan Pablo Zurita, Camila Sodi, ...
# s8648             NaN  Vijay Maurya, Naman Jain, Usha Nadkarni, Mukes...
# s1352    Noé González  Alejandro Peña Arenzana, Alejandra Yañez Reyno...
# s3807             NaN  Gavin Lewis, Theodore Barnes, Shelby Simmons, ...
# s4163             NaN    Tammy Chen, James Wen, Peggy Tseng, Denny Huang
#
#                country        date_added  release_year rating   duration  \
# show_id
# s1013           Mexico    April 19, 2021          2021  TV-MA  2 Seasons
# s8648            India  January 15, 2017          2015  TV-14        NaN
# s1352           Mexico  February 2, 2021          2020  TV-PG    123 min
# s3807    United States      May 20, 2019          2019   TV-G  2 Seasons
# s4163           Taiwan  January 27, 2019          2018  TV-MA        NaN
#
#                                                  listed_in  \
# show_id
# s1013    International TV Shows, Spanish-Language TV Sh...
# s8648                         Dramas, International Movies
# s1352    Dramas, Faith & Spirituality, International Mo...
# s3807                                Kids' TV, TV Comedies
# s4163                    International TV Shows, TV Dramas
#
#                                                description Genre Premiere  \
# show_id
# s1013    This series dramatizes the life story of Mexic...   NaN      NaN
# s8648    After terrorists place a bomb inside a toy Lor...   NaN      NaN
# s1352    In this dramatization, the Virgin Mary works a...   NaN      NaN
# s3807    A prankster prince who wants to experience lif...   NaN      NaN
# s4163    A Taipei doctor and a San Francisco engineer s...   NaN      NaN
#
#          Runtime  IMDB Score Language Originales  Mes  Ano Dia_Semana
# show_id
# s1013        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s8648        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s1352        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s3807        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s4163        NaN         0.0      NaN        NaN  NaN  NaN        NaN

# %%
df["duration_String"] = df["duration"].fillna("0 min").astype(str)
df["duration_cleaned"] = [fecha.split(' ')[0]for fecha in df.duration_String]

df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned
# show_id
# s1          Friday          90 min               90
# s2             NaN       2 Seasons                2
# s3             NaN           0 min                0
# s4             NaN           0 min                0
# s5             NaN       2 Seasons                2
# ...            ...             ...              ...
# s8803          NaN         158 min              158
# s8804          NaN       2 Seasons                2
# s8805          NaN           0 min                0
# s8806          NaN           0 min                0
# s8807          NaN         111 min              111
#
# [8807 rows x 22 columns]

# %%
df['Fecha_Insert'] = pd.to_datetime(df['date_added'], format='mixed')
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
# [8807 rows x 23 columns]

# %%
df_fecha_insert = df.groupby("Fecha_Insert")['Title'].count().sort_values(ascending=False).reset_index()
df_fecha_insert
# Out:
#      Fecha_Insert  Title
# 0      2020-01-01    110
# 1      2019-11-01     91
# 2      2018-03-01     75
# 3      2019-12-31     74
# 4      2018-10-01     71
# ...           ...    ...
# 1709   2019-12-12      1
# 1710   2013-10-08      1
# 1711   2019-12-11      1
# 1712   2013-08-02      1
# 1713   2019-03-26      1
#
# [1714 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 2: Normalización de la columna `rating`
#
# La columna `rating` tiene diferentes calificaciones como `PG`, `PG-13`, `R`, entre otras. Debes categorizar estas calificaciones en tres grupos:
#
# - **'General Audience'** para calificaciones como `G`, `PG`.
#
# - **'Teens'** para calificaciones como `PG-13`, `TV-14`.
#
# - **'Adults'** para calificaciones como `R`, `TV-MA`.

# %%
def asigna_rating(rating):
        if rating == "G" or rating == "PG":
            return "General Audience"
        elif rating == "PG-13" or rating == "TV-14":
            return "Teens"
        elif rating == "R" or rating == "TV-MA":
            return "Adults"
        elif "min" in rating:
            return "Unrated"
        else:
            return "Unrated"

# %%
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df["rating_String"] = df["rating"].fillna("Unrated").astype(str)

# %%
df["Calificaciones"] = df["rating_String"].apply(asigna_rating)

# %%
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df["Calificaciones"].unique()
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones
# show_id
# s1              PG-13             Teens
# s2              TV-MA            Adults
# s3              TV-MA            Adults
# s4              TV-MA            Adults
# s5              TV-MA            Adults
# ...               ...               ...
# s8803               R            Adults
# s8804           TV-Y7           Unrated
# s8805               R            Adults
# s8806              PG  General Audience
# s8807           TV-14             Teens
#
# [8807 rows x 25 columns]

# %%
df_calificaciones = df.groupby("Calificaciones")['Title'].count().sort_values(ascending=False).reset_index()
df_calificaciones
# Out:
#      Calificaciones  Title
# 0            Adults   4006
# 1             Teens   2650
# 2           Unrated   1823
# 3  General Audience    328

# %% [markdown]
# #### Ejercicio 3: Creación de una columna personalizada basada en el elenco
#
# Vamos a identificar si un actor clave como `Leonardo DiCaprio`, `Tom Hanks`, o `Morgan Freeman` aparece en el elenco.
#
# Usa `apply` y una función lambda para crear una nueva columna llamada `has_famous_actor` que contenga `True` si alguno de estos actores está en la lista de `cast` y `False` en caso contrario.

# %%
def has_famous_actor(actor):
        if "Leonardo DiCaprio" in actor or "Tom Hanks" in actor or "Morgan Freeman" in actor:
            return True
        else:
            return False

# %%
df["cast"].unique()
# Out:
# array([nan,
#        'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng',
#        'Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera',
#        ...,
#        'Jesse Eisenberg, Woody Harrelson, Emma Stone, Abigail Breslin, Amber Heard, Bill Murray, Derek Graf',
#        'Tim Allen, Courteney Cox, Chevy Chase, Kate Mara, Ryan Newman, Michael Cassidy, Spencer Breslin, Rip Torn, Kevin Zegers',
#        'Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy'],
#       dtype=object)

# %%
df["cast"] = df["cast"].fillna("No actors").astype(str)

# %%
df["Actores_Famosos"] = df["cast"].apply(lambda actor: (("Leonardo DiCaprio" in actor or "Tom Hanks" in actor or "Morgan Freeman" in actor) == True))

# %%
#  Lo había hecho siguiente la dinámica anterior también, sin utilizar lambda
# df["Actores_Famosos"] = df["cast"].apply(has_famous_actor)
# df

# %%
df_actores_famosos = df[df["Actores_Famosos"] ==True]
df_actores_famosos
# Out:
#             type                                 Title  \
# show_id
# s130       Movie                    An Unfinished Life
# s330       Movie                   Catch Me If You Can
# s341       Movie                             Inception
# s393       Movie                      Django Unchained
# s609       Movie                  The Sum of All Fears
# s800       Movie                   Million Dollar Baby
# s1359      Movie                        Shutter Island
# s1470      Movie           What's Eating Gilbert Grape
# s1611      Movie                       Angels & Demons
# s1625      Movie                     The Da Vinci Code
# s2708      Movie                      Angel Has Fallen
# s3870      Movie                    Olympus Has Fallen
# s4001      Movie                          5 Flights Up
# s5561      Movie                            The C Word
# s6124      Movie                   Along Came a Spider
# s6273      Movie                      Before the Flood
# s6502      Movie                           Cloud Atlas
# s6590      Movie    Defying the Nazis: The Sharps' War
# s6623      Movie                        Dolphin Tale 2
# s6711      Movie                         Evan Almighty
# s6827      Movie                     Gangs of New York
# s7092      Movie                              Invictus
# s7176    TV Show              Ken Burns: The Civil War
# s7214      Movie                        Kiss the Girls
# s7271      Movie                          Last Knights
# s7736      Movie                          Philadelphia
# s7866      Movie                    Revolutionary Road
# s7950      Movie                      Saving Mr. Banks
# s8230      Movie                       The Bucket List
# s8273      Movie                          The Departed
# s8442      Movie    The Nutcracker and the Four Realms
# s8462      Movie                     The Polar Express
# s8519    TV Show  The Story of God with Morgan Freeman
# s8520    TV Show   The Story of Us with Morgan Freeman
# s8617      Movie                         Transcendence
#
#                                             director  \
# show_id
# s130                                 Lasse Hallström
# s330                                Steven Spielberg
# s341                               Christopher Nolan
# s393                               Quentin Tarantino
# s609                             Phil Alden Robinson
# s800                                  Clint Eastwood
# s1359                                Martin Scorsese
# s1470                                Lasse Hallström
# s1611                                     Ron Howard
# s1625                                     Ron Howard
# s2708                                Ric Roman Waugh
# s3870                                  Antoine Fuqua
# s4001                              Richard Loncraine
# s5561                                  Meghan O'Hara
# s6124                                   Lee Tamahori
# s6273                                 Fisher Stevens
# s6502    Lilly Wachowski, Lana Wachowski, Tom Tykwer
# s6590                   Ken Burns, Artemis Joukowsky
# s6623                           Charles Martin Smith
# s6711                                    Tom Shadyac
# s6827                                Martin Scorsese
# s7092                                 Clint Eastwood
# s7176                                      Ken Burns
# s7214                                    Gary Fleder
# s7271                                 Kazuaki Kiriya
# s7736                                 Jonathan Demme
# s7866                                     Sam Mendes
# s7950                               John Lee Hancock
# s8230                                     Rob Reiner
# s8273                                Martin Scorsese
# s8442                  Lasse Hallström, Joe Johnston
# s8462                                Robert Zemeckis
# s8519                                            NaN
# s8520                                            NaN
# s8617                                  Wally Pfister
#
#                                                       cast  \
# show_id
# s130     Robert Redford, Jennifer Lopez, Morgan Freeman...
# s330     Leonardo DiCaprio, Tom Hanks, Christopher Walk...
# s341     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# s393     Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...
# s609     Ben Affleck, Morgan Freeman, Bridget Moynahan,...
# s800     Clint Eastwood, Hilary Swank, Morgan Freeman, ...
# s1359    Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...
# s1470    Johnny Depp, Leonardo DiCaprio, Juliette Lewis...
# s1611    Tom Hanks, Ewan McGregor, Ayelet Zurer, Stella...
# s1625    Tom Hanks, Audrey Tautou, Ian McKellen, Jean R...
# s2708    Gerard Butler, Morgan Freeman, Nick Nolte, Dan...
# s3870    Gerard Butler, Aaron Eckhart, Morgan Freeman, ...
# s4001    Josh Pais, Claire van der Boom, Morgan Freeman...
# s5561                                       Morgan Freeman
# s6124    Morgan Freeman, Monica Potter, Michael Wincott...
# s6273                                    Leonardo DiCaprio
# s6502    Tom Hanks, Halle Berry, Jim Broadbent, Hugo We...
# s6590                            Tom Hanks, Marina Goldman
# s6623    Morgan Freeman, Ashley Judd, Harry Connick Jr....
# s6711    Steve Carell, John Goodman, Molly Shannon, Lau...
# s6827    Leonardo DiCaprio, Daniel Day-Lewis, Cameron D...
# s7092    Morgan Freeman, Matt Damon, Tony Kgoroge, Patr...
# s7176    Sam Waterston, Julie Harris, Jason Robards, Mo...
# s7214    Morgan Freeman, Ashley Judd, Cary Elwes, Alex ...
# s7271    Clive Owen, Morgan Freeman, Cliff Curtis, Akse...
# s7736    Tom Hanks, Denzel Washington, Jason Robards, M...
# s7866    Leonardo DiCaprio, Kate Winslet, Kathy Bates, ...
# s7950    Emma Thompson, Tom Hanks, Paul Giamatti, Jason...
# s8230    Jack Nicholson, Morgan Freeman, Sean Hayes, Be...
# s8273    Leonardo DiCaprio, Matt Damon, Jack Nicholson,...
# s8442    Mackenzie Foy, Keira Knightley, Helen Mirren, ...
# s8462    Tom Hanks, Leslie Zemeckis, Eddie Deezen, Nona...
# s8519                                       Morgan Freeman
# s8520                                       Morgan Freeman
# s8617    Johnny Depp, Rebecca Hall, Morgan Freeman, Pau...
#
#                                               country         date_added  \
# show_id
# s130                           Germany, United States  September 1, 2021
# s330                            United States, Canada     August 1, 2021
# s341                    United States, United Kingdom     August 1, 2021
# s393                                    United States      July 24, 2021
# s609                   United States, Germany, Canada       July 1, 2021
# s800                                    United States       June 2, 2021
# s1359                                   United States   February 1, 2021
# s1470                                   United States    January 1, 2021
# s1611                            United States, Italy   December 1, 2020
# s1625    United States, Malta, France, United Kingdom   December 1, 2020
# s2708                                   United States      April 4, 2020
# s3870                                   United States        May 2, 2019
# s4001                                   United States     March 17, 2019
# s5561                                   United States     March 24, 2017
# s6124                  United States, Germany, Canada    October 1, 2019
# s6273                                   United States   February 1, 2018
# s6502    Germany, United States, Hong Kong, Singapore     August 1, 2017
# s6590                                   United States        May 1, 2017
# s6623                                   United States  February 25, 2019
# s6711                                   United States     April 16, 2019
# s6827                            United States, Italy    August 20, 2019
# s7092                                   United States   November 1, 2019
# s7176                                   United States  February 22, 2017
# s7214                                   United States    January 1, 2020
# s7271                     United Kingdom, South Korea     August 1, 2019
# s7736                                   United States       July 1, 2019
# s7866                   United States, United Kingdom   November 1, 2019
# s7950        United States, United Kingdom, Australia      March 2, 2019
# s8230                                   United States    October 1, 2019
# s8273                        United States, Hong Kong    January 1, 2021
# s8442                                   United States       May 28, 2019
# s8462                                   United States    January 1, 2021
# s8519                                   United States   February 1, 2019
# s8520                                   United States   February 1, 2019
# s8617            United Kingdom, China, United States   November 1, 2018
#
#          release_year rating   duration  \
# show_id
# s130             2005  PG-13        NaN
# s330             2002  PG-13    142 min
# s341             2010  PG-13    148 min
# s393             2012      R    165 min
# s609             2002  PG-13    124 min
# s800             2004  PG-13    133 min
# s1359            2010      R    139 min
# s1470            1993  PG-13    118 min
# s1611            2009  PG-13    139 min
# s1625            2006  PG-13    149 min
# s2708            2019      R    121 min
# s3870            2013      R    119 min
# s4001            2014  PG-13        NaN
# s5561            2016  TV-14        NaN
# s6124            2001      R        NaN
# s6273            2016     PG        NaN
# s6502            2012      R    172 min
# s6590            2016  TV-14     79 min
# s6623            2014     PG    107 min
# s6711            2007     PG        NaN
# s6827            2002      R    167 min
# s7092            2009  PG-13        NaN
# s7176            1990  TV-14        NaN
# s7214            1997      R    116 min
# s7271            2015      R        NaN
# s7736            1993  PG-13    126 min
# s7866            2008      R    120 min
# s7950            2013  PG-13    126 min
# s8230            2007  PG-13        NaN
# s8273            2006      R        NaN
# s8442            2018     PG        NaN
# s8462            2004      G        NaN
# s8519            2017  TV-14  2 Seasons
# s8520            2017  TV-14        NaN
# s8617            2014  PG-13    119 min
#
#                                                  listed_in  \
# show_id
# s130                                                Dramas
# s330                                                Dramas
# s341       Action & Adventure, Sci-Fi & Fantasy, Thrillers
# s393                            Action & Adventure, Dramas
# s609                                    Action & Adventure
# s800                                 Dramas, Sports Movies
# s1359                                            Thrillers
# s1470           Classic Movies, Dramas, Independent Movies
# s1611                                            Thrillers
# s1625                                            Thrillers
# s2708                                   Action & Adventure
# s3870                                   Action & Adventure
# s4001                 Comedies, Dramas, Independent Movies
# s5561                                        Documentaries
# s6124                                            Thrillers
# s6273                                        Documentaries
# s6502              Action & Adventure, Cult Movies, Dramas
# s6590                                        Documentaries
# s6623                     Children & Family Movies, Dramas
# s6711    Children & Family Movies, Comedies, Faith & Sp...
# s6827                                               Dramas
# s7092                                Dramas, Sports Movies
# s7176                                           Docuseries
# s7214                                            Thrillers
# s7271                                   Action & Adventure
# s7736                 Classic Movies, Dramas, LGBTQ Movies
# s7866                              Dramas, Romantic Movies
# s7950                                     Comedies, Dramas
# s8230                                     Comedies, Dramas
# s8273                                    Dramas, Thrillers
# s8442                             Children & Family Movies
# s8462                             Children & Family Movies
# s8519                                           Docuseries
# s8520                                           Docuseries
# s8617                          Sci-Fi & Fantasy, Thrillers
#
#                                                description Genre Premiere  \
# show_id
# s130     A grieving widow and her daughter move in with...   NaN      NaN
# s330     An FBI agent makes it his mission to put cunni...   NaN      NaN
# s341     A troubled thief who extracts secrets from peo...   NaN      NaN
# s393     Accompanied by a German bounty hunter, a freed...   NaN      NaN
# s609     CIA agent Jack Ryan tries to discover why thre...   NaN      NaN
# s800     When a cantankerous trainer mentors a persiste...   NaN      NaN
# s1359    A U.S. marshal's troubling visions compromise ...   NaN      NaN
# s1470    In a backwater Iowa town, young Gilbert is tor...   NaN      NaN
# s1611    A Harvard symbologist races to uncover clues t...   NaN      NaN
# s1625    When the curator of the Louvre is killed, a Ha...   NaN      NaN
# s2708    Secret Service agent Mike Banning is caught in...   NaN      NaN
# s3870    A disgraced Secret Service agent must come to ...   NaN      NaN
# s4001    A couple finds unexpected drama when, after 40...   NaN      NaN
# s5561    To solve the mystery of cancer, challenging th...   NaN      NaN
# s6124    When a girl is kidnapped from a prestigious pr...   NaN      NaN
# s6273    Leonardo DiCaprio crisscrosses the globe to in...   NaN      NaN
# s6502    In this star-studded drama, six seemingly disp...   NaN      NaN
# s6590    This film documents the story of minister Wait...   NaN      NaN
# s6623    Winter the dolphin, who survived a tragic inju...   NaN      NaN
# s6711    God summons narcissistic Evan to build an ark ...   NaN      NaN
# s6827    In the crime-ridden slums of New York in the 1...   NaN      NaN
# s7092    After the end of apartheid, newly elected Pres...   NaN      NaN
# s7176    Ken Burns's documentary depicts the action of ...   NaN      NaN
# s7214    A forensic psychologist teams up with an escap...   NaN      NaN
# s7271    A nobleman who values his people's well-being ...   NaN      NaN
# s7736    Philadelphia attorney Andrew Beckett launches ...   NaN      NaN
# s7866    April and Frank's marriage unravels when a pla...   NaN      NaN
# s7950    When Walt Disney sets his sights on obtaining ...   NaN      NaN
# s8230    Two terminally ill men bust out of the cancer ...   NaN      NaN
# s8273    Two rookie Boston cops are sent deep undercove...   NaN      NaN
# s8442    When her late mother gifts her a key, Clara em...   NaN      NaN
# s8462    In this warm-hearted tale, a young boy's faith...   NaN      NaN
# s8519    Host Morgan Freeman explores religion's role i...   NaN      NaN
# s8520    Explore the forces of love, belief, power, war...   NaN      NaN
# s8617    Two computer scientists work to achieve techno...   NaN      NaN
#
#          Runtime  IMDB Score Language Originales  Mes  Ano Dia_Semana  \
# show_id
# s130         NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s330         NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s341         NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s393         NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s609         NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s800         NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s1359        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s1470        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s1611        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s1625        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s2708        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s3870        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s4001        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s5561        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s6124        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s6273        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s6502        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s6590        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s6623        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s6711        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s6827        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s7092        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s7176        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s7214        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s7271        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s7736        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s7866        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s7950        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s8230        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s8273        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s8442        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s8462        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s8519        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s8520        NaN         0.0      NaN        NaN  NaN  NaN        NaN
# s8617        NaN         0.0      NaN        NaN  NaN  NaN        NaN
#
#         duration_String duration_cleaned Fecha_Insert rating_String  \
# show_id
# s130              0 min                0   2021-09-01         PG-13
# s330            142 min              142   2021-08-01         PG-13
# s341            148 min              148   2021-08-01         PG-13
# s393            165 min              165   2021-07-24             R
# s609            124 min              124   2021-07-01         PG-13
# s800            133 min              133   2021-06-02         PG-13
# s1359           139 min              139   2021-02-01             R
# s1470           118 min              118   2021-01-01         PG-13
# s1611           139 min              139   2020-12-01         PG-13
# s1625           149 min              149   2020-12-01         PG-13
# s2708           121 min              121   2020-04-04             R
# s3870           119 min              119   2019-05-02             R
# s4001             0 min                0   2019-03-17         PG-13
# s5561             0 min                0   2017-03-24         TV-14
# s6124             0 min                0   2019-10-01             R
# s6273             0 min                0   2018-02-01            PG
# s6502           172 min              172   2017-08-01             R
# s6590            79 min               79   2017-05-01         TV-14
# s6623           107 min              107   2019-02-25            PG
# s6711             0 min                0   2019-04-16            PG
# s6827           167 min              167   2019-08-20             R
# s7092             0 min                0   2019-11-01         PG-13
# s7176             0 min                0   2017-02-22         TV-14
# s7214           116 min              116   2020-01-01             R
# s7271             0 min                0   2019-08-01             R
# s7736           126 min              126   2019-07-01         PG-13
# s7866           120 min              120   2019-11-01             R
# s7950           126 min              126   2019-03-02         PG-13
# s8230             0 min                0   2019-10-01         PG-13
# s8273             0 min                0   2021-01-01             R
# s8442             0 min                0   2019-05-28            PG
# s8462             0 min                0   2021-01-01             G
# s8519         2 Seasons                2   2019-02-01         TV-14
# s8520             0 min                0   2019-02-01         TV-14
# s8617           119 min              119   2018-11-01         PG-13
#
#            Calificaciones  Actores_Famosos
# show_id
# s130                Teens             True
# s330                Teens             True
# s341                Teens             True
# s393               Adults             True
# s609                Teens             True
# s800                Teens             True
# s1359              Adults             True
# s1470               Teens             True
# s1611               Teens             True
# s1625               Teens             True
# s2708              Adults             True
# s3870              Adults             True
# s4001               Teens             True
# s5561               Teens             True
# s6124              Adults             True
# s6273    General Audience             True
# s6502              Adults             True
# s6590               Teens             True
# s6623    General Audience             True
# s6711    General Audience             True
# s6827              Adults             True
# s7092               Teens             True
# s7176               Teens             True
# s7214              Adults             True
# s7271              Adults             True
# s7736               Teens             True
# s7866              Adults             True
# s7950               Teens             True
# s8230               Teens             True
# s8273              Adults             True
# s8442    General Audience             True
# s8462    General Audience             True
# s8519               Teens             True
# s8520               Teens             True
# s8617               Teens             True

# %%
# Dos formas de contar los valores:
df_total_actores_famosos = df[df["Actores_Famosos"] ==True].shape[0]
df_total_actores_famosos_A = df["Actores_Famosos"].sum()

print(df_total_actores_famosos)
print(df_total_actores_famosos_A)
# Out:
# 35
# 35

# %%
df_famosos = df.groupby("Actores_Famosos")['Title'].count().sort_values(ascending=False).reset_index()
df_famosos
# Out:
#    Actores_Famosos  Title
# 0            False   8772
# 1             True     35

# %% [markdown]
# #### Ejercicio 4: Creación de una columna personalizada usando lógica condicional
#
# Vamos a crear una columna llamada `is_recent` que identifique si un título fue lanzado en los últimos 5 años.
#
# Crea una función para marcar con `True` si el título es reciente (lanzado en los últimos 5 años) y `False` si no lo es.

# %%
df["Años_desde_lanzamiento"] = (pd.to_datetime("today").year - df["release_year"])
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento
# show_id
# s1                            4
# s2                            3
# s3                            3
# s4                            3
# s5                            3
# ...                         ...
# s8803                        17
# s8804                         6
# s8805                        15
# s8806                        18
# s8807                         9
#
# [8807 rows x 27 columns]

# %%
def es_reciente(años_desde_lanzamiento):
        if años_desde_lanzamiento < 5:
            return True
        else:
            return False

# %%
df["is_recent"] = df["Años_desde_lanzamiento"].apply(es_reciente)
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento  is_recent
# show_id
# s1                            4       True
# s2                            3       True
# s3                            3       True
# s4                            3       True
# s5                            3       True
# ...                         ...        ...
# s8803                        17      False
# s8804                         6      False
# s8805                        15      False
# s8806                        18      False
# s8807                         9      False
#
# [8807 rows x 28 columns]

# %%
df_recientes = df.groupby("is_recent")['Title'].count().sort_values(ascending=False).reset_index()
df_recientes
# Out:
#    is_recent  Title
# 0      False   7262
# 1       True   1545

# %% [markdown]
# #### Ejercicio 5: Clasificación de películas por década
#
# En este ejercicio, tu objetivo es categorizar los años de lanzamiento de las películas o series en décadas. La columna `release_year` contiene el año de lanzamiento y debes crear una nueva columna llamada `decade` que indique la década correspondiente, como "1990s", "2000s", etc.

# %%
anos_ordenaods = np.sort(df["release_year"].unique())
print(anos_ordenaods)
# Out:
# [1925 1942 1943 1944 1945 1946 1947 1954 1955 1956 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021]

# %%
def categoriza_decada(año):
        if año >= 1920 and año < 1930:
            return "1920s"
        elif año >= 1930 and año < 1940:
            return "1930s"
        elif año >= 1940 and año < 1950:
            return "1940s"
        elif año >= 1950 and año < 1960:
            return "1950s"
        elif año >= 1960 and año < 1970:
            return "1960s"
        elif año >= 1970 and año < 1980:
            return "1970s"
        elif año >= 1980 and año < 1990:
            return "1980s"
        elif año >= 1990 and año < 2000:
            return "1990s"
        elif año >= 2000 and año < 2010:
            return "2000s"
        elif año >= 2010 and año < 2020:
            return "2010s"
        elif año >= 2020 and año < 2030:
            return "2020s"
        else:
            return "No decade"

# %%
df["Decade"] = df["release_year"].apply(categoriza_decada)
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento  is_recent Decade
# show_id
# s1                            4       True  2020s
# s2                            3       True  2020s
# s3                            3       True  2020s
# s4                            3       True  2020s
# s5                            3       True  2020s
# ...                         ...        ...    ...
# s8803                        17      False  2000s
# s8804                         6      False  2010s
# s8805                        15      False  2000s
# s8806                        18      False  2000s
# s8807                         9      False  2010s
#
# [8807 rows x 29 columns]

# %%
np.sort(df["Decade"].unique())
# Out:
# array(['1920s', '1940s', '1950s', '1960s', '1970s', '1980s', '1990s',
#        '2000s', '2010s', '2020s'], dtype=object)

# %%
df_titulos_decadas = df.groupby("Decade")['Title'].count().sort_values(ascending=False).reset_index()
df_titulos_decadas
# Out:
#   Decade  Title
# 0  2010s   5927
# 1  2020s   1545
# 2  2000s    810
# 3  1990s    274
# 4  1980s    129
# 5  1970s     70
# 6  1960s     25
# 7  1940s     15
# 8  1950s     11
# 9  1920s      1

# %% [markdown]
# #### Ejercicio 6: Extracción de información
#
# Para practicar la extracción de información:
#
# 1. **Extrae el primer actor** de la lista en la columna `cast` y crea una nueva columna llamada `first_actor`.
#
# 2. **Extrae el primer nombre del director** y guárdalo en una columna llamada `first_name_director`.

# %%
df["cast"].unique()
# Out:
# array(['No actors',
#        'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng',
#        'Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera',
#        ...,
#        'Jesse Eisenberg, Woody Harrelson, Emma Stone, Abigail Breslin, Amber Heard, Bill Murray, Derek Graf',
#        'Tim Allen, Courteney Cox, Chevy Chase, Kate Mara, Ryan Newman, Michael Cassidy, Spencer Breslin, Rip Torn, Kevin Zegers',
#        'Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy'],
#       dtype=object)

# %%
def primer_actor(lista):
    if lista == "No actors":
        return "No info"
    else:
        actores = lista.split(",")
        return actores[0]

# %%
df["cast"] = df["cast"].fillna("No actors").astype(str)

# %%
df["first_actor"] = df["cast"].apply(primer_actor)
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento  is_recent Decade      first_actor
# show_id
# s1                            4       True  2020s          No info
# s2                            3       True  2020s       Ama Qamata
# s3                            3       True  2020s    Sami Bouajila
# s4                            3       True  2020s          No info
# s5                            3       True  2020s       Mayur More
# ...                         ...        ...    ...              ...
# s8803                        17      False  2000s     Mark Ruffalo
# s8804                         6      False  2010s          No info
# s8805                        15      False  2000s  Jesse Eisenberg
# s8806                        18      False  2000s        Tim Allen
# s8807                         9      False  2010s    Vicky Kaushal
#
# [8807 rows x 30 columns]

# %%
df["director"].dtype
# Out:
# dtype('O')

# %%
df["director"] = df["director"].fillna("No_info")

# %%
df["first_name_director"] = [nombre.split(' ')[0]for nombre in df.director]
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          No_info
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          No_info
# s5       TV Show           Kota Factory          No_info
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb          No_info
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento  is_recent Decade      first_actor  \
# show_id
# s1                            4       True  2020s          No info
# s2                            3       True  2020s       Ama Qamata
# s3                            3       True  2020s    Sami Bouajila
# s4                            3       True  2020s          No info
# s5                            3       True  2020s       Mayur More
# ...                         ...        ...    ...              ...
# s8803                        17      False  2000s     Mark Ruffalo
# s8804                         6      False  2010s          No info
# s8805                        15      False  2000s  Jesse Eisenberg
# s8806                        18      False  2000s        Tim Allen
# s8807                         9      False  2010s    Vicky Kaushal
#
#         first_name_director
# show_id
# s1                  Kirsten
# s2                  No_info
# s3                   Julien
# s4                  No_info
# s5                  No_info
# ...                     ...
# s8803                 David
# s8804               No_info
# s8805                 Ruben
# s8806                 Peter
# s8807                 Mozez
#
# [8807 rows x 31 columns]

# %% [markdown]
# #### Ejercicio 7: Limpieza de la columna `cast`
#
# La columna `cast` contiene una lista de actores separados por comas. Tu objetivo es realizar las siguientes tareas:
#
# 1. **Reemplaza los valores nulos** en la columna `cast` por "sin información".
#
# 2. **Contar el número de actores** en cada entrada y crear una nueva columna llamada `num_cast`.
#
# 3. **Normalizar los nombres**: Asegúrate de que los nombres de los actores estén en un formato consistente (por ejemplo, quitar espacios adicionales).

# %%
df["cast"] = df["cast"].str.lstrip()
df["cast"] = df["cast"].str.rstrip()

# %%
def primer_actor(cast):
    
    if cast == "No actors":
        return 0
    else:
        lista_actores = cast.split(",")
        return len(lista_actores)

# %%
actors = "Ama Qamata, Khosi Ngema, Gail Mabalane, Sami Bouajila, Tracy Gotoas, Samuel Jouy, Mayur More, Jitendra Kumar"
actores = actors.split(",")
len(actores)
# Out:
# 8

# %%
df["num_cast"] = df["cast"].apply(primer_actor)
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          No_info
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          No_info
# s5       TV Show           Kota Factory          No_info
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb          No_info
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento  is_recent Decade      first_actor  \
# show_id
# s1                            4       True  2020s          No info
# s2                            3       True  2020s       Ama Qamata
# s3                            3       True  2020s    Sami Bouajila
# s4                            3       True  2020s          No info
# s5                            3       True  2020s       Mayur More
# ...                         ...        ...    ...              ...
# s8803                        17      False  2000s     Mark Ruffalo
# s8804                         6      False  2010s          No info
# s8805                        15      False  2000s  Jesse Eisenberg
# s8806                        18      False  2000s        Tim Allen
# s8807                         9      False  2010s    Vicky Kaushal
#
#         first_name_director  num_cast
# show_id
# s1                  Kirsten         0
# s2                  No_info        19
# s3                   Julien         9
# s4                  No_info         0
# s5                  No_info         8
# ...                     ...       ...
# s8803                 David        10
# s8804               No_info         0
# s8805                 Ruben         7
# s8806                 Peter         9
# s8807                 Mozez         8
#
# [8807 rows x 32 columns]

# %%
# Confirmar que la pelicula zodcas tiene 10 actores:
cast_zodiac = df.loc[df["Title"] == "Zodiac", "cast"].values[0]

print(cast_zodiac)
print(len(cast_zodiac.split(",")))
# Out:
# Mark Ruffalo, Jake Gyllenhaal, Robert Downey Jr., Anthony Edwards, Brian Cox, Elias Koteas, Donal Logue, John Carroll Lynch, Dermot Mulroney, Chloë Sevigny
# 10

# %% [markdown]
# #### Ejercicio 9: Identificación de Directores Recurrentes
#
# En este ejercicio, debes identificar los directores que aparecen más de una vez en el conjunto de datos. Realiza los siguientes pasos:
#
# 1. **Reemplaza los valores nulos** en la columna `director` por "sin información".
#
# 3. **Cuenta cuántas veces aparece cada director** en la columna creada en el ejercicio 6.
#
# 4. **Filtra aquellos directores que aparecen más de una vez** y crea una nueva columna llamada `recurrent_director` donde se indique "Yes" si el director aparece varias veces o "No" en caso contrario.

# %%
# Ya había reemplazado los valores, por lo que no hay nulos y no insertará "Sin informacion" 
df["director"] = df["director"].fillna("Sin informacion").astype(str)
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          No_info
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          No_info
# s5       TV Show           Kota Factory          No_info
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb          No_info
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento  is_recent Decade      first_actor  \
# show_id
# s1                            4       True  2020s          No info
# s2                            3       True  2020s       Ama Qamata
# s3                            3       True  2020s    Sami Bouajila
# s4                            3       True  2020s          No info
# s5                            3       True  2020s       Mayur More
# ...                         ...        ...    ...              ...
# s8803                        17      False  2000s     Mark Ruffalo
# s8804                         6      False  2010s          No info
# s8805                        15      False  2000s  Jesse Eisenberg
# s8806                        18      False  2000s        Tim Allen
# s8807                         9      False  2010s    Vicky Kaushal
#
#         first_name_director  num_cast
# show_id
# s1                  Kirsten         0
# s2                  No_info        19
# s3                   Julien         9
# s4                  No_info         0
# s5                  No_info         8
# ...                     ...       ...
# s8803                 David        10
# s8804               No_info         0
# s8805                 Ruben         7
# s8806                 Peter         9
# s8807                 Mozez         8
#
# [8807 rows x 32 columns]

# %%
# lambda argumentos: valor_si_verdadero if condicion else valor_si_falso

# Utilizo una expresión lambda 
df["director"] = df["director"].apply(lambda director: "Sin informacion" if director == "No_info" else director)
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water  Sin informacion
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans  Sin informacion
# s5       TV Show           Kota Factory  Sin informacion
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb  Sin informacion
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento  is_recent Decade      first_actor  \
# show_id
# s1                            4       True  2020s          No info
# s2                            3       True  2020s       Ama Qamata
# s3                            3       True  2020s    Sami Bouajila
# s4                            3       True  2020s          No info
# s5                            3       True  2020s       Mayur More
# ...                         ...        ...    ...              ...
# s8803                        17      False  2000s     Mark Ruffalo
# s8804                         6      False  2010s          No info
# s8805                        15      False  2000s  Jesse Eisenberg
# s8806                        18      False  2000s        Tim Allen
# s8807                         9      False  2010s    Vicky Kaushal
#
#         first_name_director  num_cast
# show_id
# s1                  Kirsten         0
# s2                  No_info        19
# s3                   Julien         9
# s4                  No_info         0
# s5                  No_info         8
# ...                     ...       ...
# s8803                 David        10
# s8804               No_info         0
# s8805                 Ruben         7
# s8806                 Peter         9
# s8807                 Mozez         8
#
# [8807 rows x 32 columns]

# %%
def filtra_director(director, lista):
 
    if director not in lista:
        lista.append(director)
        return "No"
    else:
        return "Yes"

# %%
lista_directores = []

df["recurrent_directors"] = df["director"].apply(lambda director: filtra_director(director, lista_directores))
df
# Out:
#             type                  Title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water  Sin informacion
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans  Sin informacion
# s5       TV Show           Kota Factory  Sin informacion
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb  Sin informacion
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                               No actors  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                               No actors            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                            No actors            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA        NaN
# s4       September 24, 2021          2021  TV-MA        NaN
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R        NaN
# s8806      January 11, 2020          2006     PG        NaN
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description        Genre  \
# show_id
# s1       As her father nears the end of his life, filmm...  Documentary
# s2       After crossing paths at a party, a Cape Town t...          NaN
# s3       To protect his family from a powerful drug lor...          NaN
# s4       Feuds, flirtations and toilet talk go down amo...          NaN
# s5       In a city of coaching centers known to train I...          NaN
# ...                                                    ...          ...
# s8803    A political cartoonist, a crime reporter and a...          NaN
# s8804    While living alone in a spooky town, a young g...          NaN
# s8805    Looking to survive in a world taken over by zo...          NaN
# s8806    Dragged from civilian life, a former superhero...          NaN
# s8807    A scrappy but poor boy worms his way into a ty...          NaN
#
#            Premiere  Runtime  IMDB Score Language Originales      Mes     Ano  \
# show_id
# s1       2020-10-02     90.0         7.5  English       True  October  2020.0
# s2              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s3              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s4              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s5              NaN      NaN         0.0      NaN        NaN      NaN     NaN
# ...             ...      ...         ...      ...        ...      ...     ...
# s8803           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8804           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8805           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8806           NaN      NaN         0.0      NaN        NaN      NaN     NaN
# s8807           NaN      NaN         0.0      NaN        NaN      NaN     NaN
#
#         Dia_Semana duration_String duration_cleaned Fecha_Insert  \
# show_id
# s1          Friday          90 min               90   2021-09-25
# s2             NaN       2 Seasons                2   2021-09-24
# s3             NaN           0 min                0   2021-09-24
# s4             NaN           0 min                0   2021-09-24
# s5             NaN       2 Seasons                2   2021-09-24
# ...            ...             ...              ...          ...
# s8803          NaN         158 min              158   2019-11-20
# s8804          NaN       2 Seasons                2   2019-07-01
# s8805          NaN           0 min                0   2019-11-01
# s8806          NaN           0 min                0   2020-01-11
# s8807          NaN         111 min              111   2019-03-02
#
#         rating_String    Calificaciones  Actores_Famosos  \
# show_id
# s1              PG-13             Teens            False
# s2              TV-MA            Adults            False
# s3              TV-MA            Adults            False
# s4              TV-MA            Adults            False
# s5              TV-MA            Adults            False
# ...               ...               ...              ...
# s8803               R            Adults            False
# s8804           TV-Y7           Unrated            False
# s8805               R            Adults            False
# s8806              PG  General Audience            False
# s8807           TV-14             Teens            False
#
#          Años_desde_lanzamiento  is_recent Decade      first_actor  \
# show_id
# s1                            4       True  2020s          No info
# s2                            3       True  2020s       Ama Qamata
# s3                            3       True  2020s    Sami Bouajila
# s4                            3       True  2020s          No info
# s5                            3       True  2020s       Mayur More
# ...                         ...        ...    ...              ...
# s8803                        17      False  2000s     Mark Ruffalo
# s8804                         6      False  2010s          No info
# s8805                        15      False  2000s  Jesse Eisenberg
# s8806                        18      False  2000s        Tim Allen
# s8807                         9      False  2010s    Vicky Kaushal
#
#         first_name_director  num_cast recurrent_directors
# show_id
# s1                  Kirsten         0                  No
# s2                  No_info        19                  No
# s3                   Julien         9                  No
# s4                  No_info         0                 Yes
# s5                  No_info         8                 Yes
# ...                     ...       ...                 ...
# s8803                 David        10                 Yes
# s8804               No_info         0                 Yes
# s8805                 Ruben         7                 Yes
# s8806                 Peter         9                  No
# s8807                 Mozez         8                  No
#
# [8807 rows x 33 columns]

# %%
df_directores_recurr = df.groupby(["director", "recurrent_directors"])['Title'].count().sort_values(ascending=False).reset_index()
df_directores_recurr
# Out:
#                     director recurrent_directors  Title
# 0            Sin informacion                 Yes   2633
# 1              Rajiv Chilaka                 Yes     18
# 2     Raúl Campos, Jan Suter                 Yes     17
# 3               Marcus Raboy                 Yes     15
# 4                Suhas Kadav                 Yes     15
# ...                      ...                 ...    ...
# 5392     Óskar Thór Axelsson                  No      1
# 5393        Ömer Faruk Sorak                  No      1
# 5394        Ömer Faruk Sorak                 Yes      1
# 5395            Şenol Sönmez                  No      1
# 5396             Zuko Nodada                  No      1
#
# [5397 rows x 3 columns]

# %%
dir_counts = df["director"].value_counts()
dir_counts
# Out:
# director
# Sin informacion                           2634
# Rajiv Chilaka                               19
# Raúl Campos, Jan Suter                      18
# Suhas Kadav                                 16
# Marcus Raboy                                16
#                                           ...
# Milla Harrison-Hansley, Alicky Sussman       1
# Drew Stone                                   1
# Benjamin Turner                              1
# S. Shankar                                   1
# Peter Hewitt                                 1
# Name: count, Length: 4529, dtype: int64

# %%
df_directores = df.groupby("director")['Title'].count().sort_values(ascending=False).reset_index()
df_directores
# Out:
#                                                director  Title
# 0                                       Sin informacion   2634
# 1                                         Rajiv Chilaka     19
# 2                                Raúl Campos, Jan Suter     18
# 3                                          Marcus Raboy     16
# 4                                           Suhas Kadav     16
# ...                                                 ...    ...
# 4524                         Álvaro Delgado-Aparicio L.      1
# 4525                                    Álvaro Brechner      1
# 4526                                        Zuko Nodada      1
# 4527                                        Zsolt Pálfi      1
# 4528  Zoya Akhtar, Karan Johar, Anurag Kashyap, Diba...      1
#
# [4529 rows x 2 columns]
